# %%
import pandas as pd

# %%
df_verif = pd.read_csv("./data/ge_events_df.csv")
df_verif.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11753 entries, 0 to 11752
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           11753 non-null  int64
#  1   uid                  11753 non-null  int64
#  2   canonicalurl         11753 non-null  str
#  3   title_fr             11690 non-null  str
#  4   description_fr       11690 non-null  str
#  5   longdescription_fr   10289 non-null  str
#  6   keywords_fr          4427 non-null   str
#  7   conditions_fr        5922 non-null   str
#  8   timings              11753 non-null  str
#  9   daterange_fr         11753 non-null  str
#  10  firstdate_begin      11753 non-null  str
#  11  lastdate_end         11753 non-null  str
#  12  location_name        11753 non-null  str
#  13  location_address     11753 non-null  str
#  14  location_postalcode  11684 non-null  str
#  15  location_city        11739 non-null  str
# ...

# %%
df_verif.columns
# Out:
# Index(['Unnamed: 0', 'uid', 'canonicalurl', 'title_fr', 'description_fr',
#        'longdescription_fr', 'keywords_fr', 'conditions_fr', 'timings',
#        'daterange_fr', 'firstdate_begin', 'lastdate_end', 'location_name',
#        'location_address', 'location_postalcode', 'location_city',
#        'location_department', 'location_region', 'age_min', 'age_max',
#        'registration', 'event_actif', 'texte_rag'],
#       dtype='str')

# %%
df_mulhouse = df_verif[
    (df_verif["location_city"] == "Charleville-Mézières") &
    (
        df_verif["description_fr"].str.contains("atelier", case=False, na=False) |
        df_verif["conditions_fr"].str.contains("ateliers", case=False, na=False)
    )
]
df_mulhouse
# Out:
#        Unnamed: 0       uid  \
# 2433         2433  16042587
# 2997         2997  88007187
# 5717         5717  32196061
# 7610         7610  86490731
# 10927       10927   4266645
#
#                                             canonicalurl  \
# 2433   https://openagenda.com/rdvj-2025-grand-est/eve...
# 2997   https://openagenda.com/planlibre/events/atelie...
# 5717   https://openagenda.com/culture/events/visite-a...
# 7610   https://openagenda.com/planlibre/events/visite...
# 10927  https://openagenda.com/place-locale/events/ani...
#
#                                                 title_fr  \
# 2433   Visite guidée du jardin du Parc zoologique et ...
# 2997           Ateliers pour les enfants et les familles
# 5717   Visite-atelier : Trouve le radiateur pour l'at...
# 7610               Visite en famille - inventer l'espace
# 10927                          Animations estivales 2026
#
#                                           description_fr  \
# ...
