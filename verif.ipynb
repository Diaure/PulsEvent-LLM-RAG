# %%
import pandas as pd

# %%
df_verif = pd.read_csv("./data/ge_events_df.csv")
df_verif.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11753 entries, 0 to 11752
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           11753 non-null  int64
#  1   uid                  11753 non-null  int64
#  2   canonicalurl         11753 non-null  str
#  3   title_fr             11690 non-null  str
#  4   description_fr       11690 non-null  str
#  5   longdescription_fr   10289 non-null  str
#  6   keywords_fr          4427 non-null   str
#  7   conditions_fr        5922 non-null   str
#  8   timings              11753 non-null  str
#  9   daterange_fr         11753 non-null  str
#  10  firstdate_begin      11753 non-null  str
#  11  lastdate_end         11753 non-null  str
#  12  location_name        11753 non-null  str
#  13  location_address     11753 non-null  str
#  14  location_postalcode  11684 non-null  str
#  15  location_city        11739 non-null  str
# ...

# %%
df_concert = df_verif[
    (df_verif["location_city"] == "Strasbourg") &
    (
        df_verif["description_fr"].str.contains("concert", case=False, na=False) |
        df_verif["description_fr"].str.contains("musique", case=False, na=False)
    )
]
df_concert
# Out:
#        Unnamed: 0       uid  \
# 467           467  48027529
# 746           746  17944251
# 1635         1635  23164884
# 3855         3855  72729784
# 4429         4429  96692655
# 5225         5225  98432620
# 5531         5531  77444307
# 5766         5766   7769455
# 6728         6728  49393057
# 7652         7652  30791375
# 8350         8350  24324761
# 8519         8519  35188031
# 8871         8871  86002035
# 9633         9633  97855853
# 9711         9711  11484102
# 11111       11111   8585450
# 11303       11303  21377268
#
#                                             canonicalurl  \
# 467    https://openagenda.com/la-nuit-des-eglises-202...
# 746    https://openagenda.com/ndm-2025-grand-est/even...
# 1635   https://openagenda.com/ndm-2025-grand-est/even...
# 3855   https://openagenda.com/les-evenements-de-la-li...
# 4429   https://openagenda.com/unidivers-oui-sortir/ev...
# 5225   https://openagenda.com/les-evenements-de-la-li...
# ...

# %%
df_concert
