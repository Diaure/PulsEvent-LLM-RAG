# %%
import pandas as pd

# %%
df_verif = pd.read_csv("./data/ge_events_df.csv")
df_verif.head(5)
# Out:
#    Unnamed: 0       uid                                       canonicalurl  \
# 0           0  90172032  https://openagenda.com/villedecmz/events/conco...
# 1           1    257704  https://openagenda.com/villedecmz/events/tourn...
# 2           2  20351829  https://openagenda.com/villedecmz/events/porte...
# 3           3  54005490  https://openagenda.com/villedecmz/events/apres...
# 4           4  64445421  https://openagenda.com/ardenne-metropole/event...
#
#                                   title_fr  \
# 0                       Concours de belote
# 1                     tournoi de ping-pong
# 2                Portes ouvertes l'Atelier
# 3                       Après-midi dansant
# 4  Boom Crêpes Party mercredi 12 mars 2025
#
#                                       description_fr  \
# 0                                 Concours de belote
# 1                                          ping-pong
# 2                                          l'Atelier
# 3                                 Après-midi dansant
# 4  Boom Crêpes Party mercredi 12 mars 2025 de 14h...
#
#               longdescription_fr conditions_fr  \
# 0  <p>Début des jeux 20 h 30</p>           NaN
# 1                            NaN           NaN
# 2                            NaN  entrée libre
# 3                            NaN           NaN
# 4                            NaN           NaN
#
#                       daterange_fr            firstdate_begin  \
# 0   Vendredi 7 février 2025, 19h30  2025-02-07T18:30:00+00:00
# 1            25 et 26 janvier 2025  2025-01-25T13:00:00+00:00
# 2    Samedi 18 janvier 2025, 14h00  2025-01-18T13:00:00+00:00
# 3  Dimanche 12 janvier 2025, 14h00  2025-01-12T13:00:00+00:00
# 4     Mercredi 12 mars 2025, 14h00  2025-03-12T13:00:00+00:00
#
#                 lastdate_end                location_name  \
# 0  2025-02-07T21:00:00+00:00            Salle Arc en Ciel
# 1  2025-01-26T12:00:00+00:00           Salle Reine Bestel
# 2  2025-01-18T17:00:00+00:00                    L'Atelier
# 3  2025-01-12T17:00:00+00:00             75 Forest Avenue
# 4  2025-03-12T16:15:00+00:00  Patinoire Elena Issatchenko
#
#                                     location_address location_postalcode  \
# 0      26 bis rue d'Etion 08000 Charleville-Mézières               08000
# 1   14 chemin du Mémorial 08000 Charleville-Mézières               08000
# 2     3 C rue Louis Hanot 08000 Charleville-Mézières               08000
# 3        75 avenue Forest 08000 Charleville-Mézières               08000
# 4  Promenade De La Warenne 08000 Charleville-Mézi...               08000
#
#           location_city location_department location_region  age_min  age_max  \
# 0  Charleville-Mézières            Ardennes       Grand Est      NaN      NaN
# 1  Charleville-Mézières            Ardennes       Grand Est      NaN      NaN
# 2  Charleville-Mézières            Ardennes       Grand Est      NaN      NaN
# 3  Charleville-Mézières            Ardennes       Grand Est      NaN      NaN
# 4  Charleville-Mézières            Ardennes       Grand Est      NaN      NaN
#
#                                         registration  \
# 0         [{"type": "phone", "value": "0601715119"}]
# 1                                                NaN
# 2                                                NaN
# 3  [{"type": "link", "value": "https://www.75fore...
# 4  [{"type": "link", "value": "https://equipement...
#
#                                            texte_rag
# 0  Titre: Concours de belote\r\nDescription: Conc...
# 1  Titre: tournoi de ping-pong\r\nDescription: pi...
# 2  Titre: Portes ouvertes l'Atelier\r\nDescriptio...
# 3  Titre: Après-midi dansant\r\nDescription: Aprè...
# 4  Titre: Boom Crêpes Party mercredi 12 mars 2025...

# %%
df_verif.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 11087 entries, 0 to 11086
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           11087 non-null  int64
#  1   uid                  11087 non-null  int64
#  2   canonicalurl         11087 non-null  str
#  3   title_fr             11024 non-null  str
#  4   description_fr       11024 non-null  str
#  5   longdescription_fr   9638 non-null   str
#  6   conditions_fr        5591 non-null   str
#  7   daterange_fr         11087 non-null  str
#  8   firstdate_begin      11087 non-null  str
#  9   lastdate_end         11087 non-null  str
#  10  location_name        11087 non-null  str
#  11  location_address     11087 non-null  str
#  12  location_postalcode  11026 non-null  str
#  13  location_city        11073 non-null  str
#  14  location_department  11087 non-null  str
#  15  location_region      11087 non-null  str
#  16  age_min              1380 non-null   float64
#  17  age_max              2160 non-null   float64
#  18  registration         6120 non-null   str
#  19  texte_rag            11087 non-null  str
# dtypes: float64(2), int64(2), str(16)
# memory usage: 24.4 MB

# %%
max(df_verif["firstdate_begin"])
# Out:
# '2026-12-19T14:00:00+00:00'

# %%
min(df_verif["firstdate_begin"])
# Out:
# '2025-01-01T18:00:00+00:00'

# %%
max(df_verif["lastdate_end"])
# Out:
# '2043-06-04T12:00:00+00:00'

# %%
min(df_verif["lastdate_end"])
# Out:
# '2025-01-04T16:30:00+00:00'

# %%
df_verif['location_city'].unique()
# Out:
# <ArrowStringArray>
# ['Charleville-Mézières',           'Strasbourg',    'Villers-lès-Nancy',
#            'Lapoutroie',                'Laxou',               'Colmar',
#             'Fellering',    'Sainte-Marguerite',                'Reims',
#                 'NANCY',
#  ...
#    'Brienne-la-Vieille',          'Fromelennes',          'Saint-Oulph',
#            'Ortoncourt',         'Willgottheim',        'Pierrevillers',
#       'Montigny le Roi',             'Distroff',                'Lesse',
#      'Bourgogne-Fresne']
# Length: 1391, dtype: str
