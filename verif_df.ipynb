# %%
import pandas as pd

# %%
df_verif = pd.read_csv("./data/ge_events_df.csv")
df_verif.head(5)
# Out:
#    Unnamed: 0       uid                                       canonicalurl  \
# 0           0  29056606  https://openagenda.com/villedecmz/events/conse...
# 1           1  90172032  https://openagenda.com/villedecmz/events/conco...
# 2           2    257704  https://openagenda.com/villedecmz/events/tourn...
# 3           3  20351829  https://openagenda.com/villedecmz/events/porte...
# 4           4  54005490  https://openagenda.com/villedecmz/events/apres...
#
#                     title_fr      description_fr  \
# 0          Conseil municipal   Conseil municipal
# 1         Concours de belote  Concours de belote
# 2       tournoi de ping-pong           ping-pong
# 3  Portes ouvertes l'Atelier           l'Atelier
# 4         Après-midi dansant  Après-midi dansant
#
#               longdescription_fr conditions_fr  \
# 0                            NaN           NaN
# 1  <p>Début des jeux 20 h 30</p>           NaN
# 2                            NaN           NaN
# 3                            NaN  entrée libre
# 4                            NaN           NaN
#
#                                              timings  \
# 0  [{"begin": "2024-11-21T18:30:00+01:00", "end":...
# 1  [{"begin": "2025-02-07T19:30:00+01:00", "end":...
# 2  [{"begin": "2025-01-25T14:00:00+01:00", "end":...
# 3  [{"begin": "2025-01-18T14:00:00+01:00", "end":...
# 4  [{"begin": "2025-01-12T14:00:00+01:00", "end":...
#
#                                         daterange_fr  \
# 0  21 novembre 2024 - 18 décembre 2025, certains ...
# 1                     Vendredi 7 février 2025, 19h30
# 2                              25 et 26 janvier 2025
# 3                      Samedi 18 janvier 2025, 14h00
# 4                    Dimanche 12 janvier 2025, 14h00
#
#              firstdate_begin  ...  \
# 0  2024-11-21T17:30:00+00:00  ...
# 1  2025-02-07T18:30:00+00:00  ...
# 2  2025-01-25T13:00:00+00:00  ...
# 3  2025-01-18T13:00:00+00:00  ...
# 4  2025-01-12T13:00:00+00:00  ...
#
#                                     location_address location_postalcode  \
# 0  Place de l'Hôtel de Ville 08000 Charleville-Mé...               08000
# 1      26 bis rue d'Etion 08000 Charleville-Mézières               08000
# 2   14 chemin du Mémorial 08000 Charleville-Mézières               08000
# 3     3 C rue Louis Hanot 08000 Charleville-Mézières               08000
# 4        75 avenue Forest 08000 Charleville-Mézières               08000
#
#           location_city location_department location_region age_min age_max  \
# 0  Charleville-Mézières            Ardennes       Grand Est     NaN     NaN
# 1  Charleville-Mézières            Ardennes       Grand Est     NaN     NaN
# 2  Charleville-Mézières            Ardennes       Grand Est     NaN     NaN
# 3  Charleville-Mézières            Ardennes       Grand Est     NaN     NaN
# 4  Charleville-Mézières            Ardennes       Grand Est     NaN     NaN
#
#                                         registration  event_actif  \
# 0                                                NaN        False
# 1         [{"type": "phone", "value": "0601715119"}]        False
# 2                                                NaN        False
# 3                                                NaN        False
# 4  [{"type": "link", "value": "https://www.75fore...        False
#
#                                            texte_rag
# 0  Titre: Conseil municipal\nDescription: Conseil...
# 1  Titre: Concours de belote\nDescription: Concou...
# 2  Titre: tournoi de ping-pong\nDescription: ping...
# 3  Titre: Portes ouvertes l'Atelier\nDescription:...
# 4  Titre: Après-midi dansant\nDescription: Après-...
#
# [5 rows x 22 columns]

# %%
# récupérer les vraies dates de debut et fin de l'évènement
import json
def extract_first_timing(cell):
    if cell is None:
        return None

    # Si c'est une string JSON → on la charge
    if isinstance(cell, str):
        try:
            timings = json.loads(cell)
        except Exception:
            return None
    else:
        # Si c'est déjà une liste Python
        timings = cell

    # si la liste est vide
    if not timings:
        return None, None

    # On prend la première occurrence
    t0 = timings[0]
    return t0.get("begin")

df_verif["begin"] = df_verif["timings"].apply(extract_first_timing)
df_verif["begin"] = pd.to_datetime(df_verif["begin"], utc=True)

# %%
df_verif.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11753 entries, 0 to 11752
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           11753 non-null  int64
#  1   uid                  11753 non-null  int64
#  2   canonicalurl         11753 non-null  object
#  3   title_fr             11690 non-null  object
#  4   description_fr       11690 non-null  object
#  5   longdescription_fr   10289 non-null  object
#  6   conditions_fr        5922 non-null   object
#  7   timings              11753 non-null  object
#  8   daterange_fr         11753 non-null  object
#  9   firstdate_begin      11753 non-null  object
#  10  lastdate_end         11753 non-null  object
#  11  location_name        11753 non-null  object
#  12  location_address     11753 non-null  object
#  13  location_postalcode  11684 non-null  object
#  14  location_city        11739 non-null  object
#  15  location_department  11753 non-null  object
#  16  location_region      11753 non-null  object
#  17  age_min              1394 non-null   float64
#  18  age_max              2187 non-null   float64
#  19  registration         6309 non-null   object
#  20  event_actif          11753 non-null  bool
#  21  texte_rag            11753 non-null  object
#  22  begin                11753 non-null  datetime64[ns, UTC]
# dtypes: bool(1), datetime64[ns, UTC](1), float64(2), int64(2), object(17)
# memory usage: 2.0+ MB

# %%
print(df_verif["begin"].head(20))
# Out:
# 0    2024-11-21 17:30:00+00:00
# 1    2025-02-07 18:30:00+00:00
# 2    2025-01-25 13:00:00+00:00
# 3    2025-01-18 13:00:00+00:00
# 4    2025-01-12 13:00:00+00:00
# 5    2025-03-12 13:00:00+00:00
# 6    2025-02-04 17:00:00+00:00
# 7    2025-03-15 14:00:00+00:00
# 8    2025-03-16 14:00:00+00:00
# 9    2025-02-05 08:30:00+00:00
# 10   2025-03-21 13:00:00+00:00
# 11   2025-03-22 09:30:00+00:00
# 12   2025-02-22 09:15:00+00:00
# 13   2025-01-31 08:15:00+00:00
# 14   2025-02-05 08:30:00+00:00
# 15   2025-01-30 17:30:00+00:00
# 16   2025-01-08 16:00:00+00:00
# 17   2025-03-19 09:00:00+00:00
# 18   2025-01-19 15:30:00+00:00
# 19   2025-03-23 08:00:00+00:00
# Name: begin, dtype: datetime64[ns, UTC]

# %%
today = pd.Timestamp.now(tz="UTC")
df_26_actuel = df_verif[(df_verif["begin"].dt.year == 2026) & (df_verif["begin"] >= today)]
df_26_actuel.sort_values(by="begin", ascending=True)

df_stras_concert = df_26_actuel[df_26_actuel['texte_rag'].str.contains('concert|musique', case=False, na=False)]
df_stras_concert
# Out:
#        Unnamed: 0       uid  \
# 9538         9538  80023684
# 9566         9566  72200779
# 9582         9582  76382570
# 9589         9589  17835202
# 9592         9592  41975895
# ...           ...       ...
# 11637       11637  90575491
# 11652       11652  70456613
# 11676       11676   9850087
# 11714       11714   9828943
# 11717       11717  96027626
#
#                                             canonicalurl  \
# 9538   https://openagenda.com/office-de-tourisme-de-l...
# 9566   https://openagenda.com/unidivers-oui-sortir/ev...
# 9582   https://openagenda.com/culture/events/concert-...
# 9589   https://openagenda.com/culture/events/visite-e...
# 9592   https://openagenda.com/culture/events/rencontr...
# ...                                                  ...
# 11637  https://openagenda.com/bien-grandir-dans-le-sa...
# 11652  https://openagenda.com/culture/events/julien-c...
# 11676  https://openagenda.com/rncap/events/rouge-echarpe
# 11714  https://openagenda.com/culture/events/visite-g...
# 11717  https://openagenda.com/planlibre/events/projec...
#
#                                                 title_fr  \
# 9538                                 Tambouille festival
# 9566   Concert de musique classique à Strasbourg – En...
# 9582                         Concert au Musée du Cloître
# 9589    Visite en musique de l'exposition "Persistances"
# 9592                Rencontres musicales et spirituelles
# ...                                                  ...
# 11637            Matinée des Tout-Petits: Pas peur moi !
# 11652                            Julien Clerc en concert
# 11676                                      Rouge écharpe
# 11714  Visite guidée de la bibliothèque de 10h à 12h ...
# 11717  Projection du film documentaire "Des chaises e...
#
#                                           description_fr  \
# 9538      festival itinérant de spectacles et concerts !
# 9566   Événement reporté à une date ultérieure, afin ...
# 9582   Laissez-vous transporter par un concert au mil...
# 9589   Venez vivre une expérience sensorielle unique....
# 9592   Pendant une heure, laissez-vous porter par les...
# ...                                                  ...
# 11637  Animation gratuite à destination des enfants d...
# 11652  Julien Clerc en concert exceptionnel le 10 déc...
# 11676                             Jeune public dès 3 ans
# 11714                               Biblis en folie 2026
# 11717  **Envirobat Grand Est – ARCAD LQE** et la **Vi...
#
#                                       longdescription_fr  \
# 9538   <p>Rendez-vous le 6 août à Bult pour le Tambou...
# 9566   <p>Porté par la devise « La musique fait du bi...
# 9582   <p>Laissez-vous transporter par un concert au ...
# 9589   <p>Venez vivre une expérience sensorielle uniq...
# 9592   <p>Pendant une heure, laissez-vous porter par ...
# ...                                                  ...
# 11637  <p>Un espace cocooning et sécurisé est réservé...
# 11652  <p>Julien Clerc, c’est plus de 50 ans de tubes...
# 11676  <p>Rouge écharpe raconte l’histoire de l’enfan...
# 11714  <p>Découvrez les différents rayons de la bibli...
# 11717  <p><strong>Envirobat Grand Est – ARCAD LQE</st...
#
#                                            conditions_fr  \
# 9538                                             Gratuit
# 9566   De 20 à 30€ tout public / gratuit moins de 12 ans
# 9582                                                 NaN
# 9589   Départ à 16h samedi et dimanche. Réservation c...
# 9592                                                 NaN
# ...                                                  ...
# 11637                                    Sur inscription
# 11652                               De 35,00 € à 85,00 €
# 11676                                                NaN
# 11714                                                NaN
# 11717                              Limité à 50 personnes
#
#                                                  timings  \
# 9538   [{"begin": "2026-08-06T09:00:00+02:00", "end":...
# 9566   [{"begin": "2026-08-14T20:00:00+02:00", "end":...
# 9582   [{"begin": "2026-09-19T15:00:00+02:00", "end":...
# 9589   [{"begin": "2026-09-19T16:00:00+02:00", "end":...
# 9592   [{"begin": "2026-09-19T18:00:00+02:00", "end":...
# ...                                                  ...
# 11637  [{"begin": "2026-10-21T09:30:00+02:00", "end":...
# 11652  [{"begin": "2026-12-10T20:30:00+01:00", "end":...
# 11676  [{"begin": "2026-12-10T17:00:00+01:00", "end":...
# 11714  [{"begin": "2026-10-03T10:00:00+02:00", "end":...
# 11717  [{"begin": "2026-10-14T09:30:00+02:00", "end":...
#
#                      daterange_fr            firstdate_begin  ...  \
# 9538          Jeudi 6 août, 09h00  2026-08-06T07:00:00+00:00  ...
# 9566      Vendredi 14 août, 20h00  2026-08-14T18:00:00+00:00  ...
# 9582   Samedi 19 septembre, 15h00  2026-09-19T13:00:00+00:00  ...
# 9589           19 et 20 septembre  2026-09-19T14:00:00+00:00  ...
# 9592           19 et 20 septembre  2026-09-19T16:00:00+00:00  ...
# ...                           ...                        ...  ...
# 11637  Mercredi 21 octobre, 09h30  2026-10-21T07:30:00+00:00  ...
# 11652    Jeudi 10 décembre, 20h30  2026-12-10T19:30:00+00:00  ...
# 11676    Jeudi 10 décembre, 17h00  2026-12-10T16:00:00+00:00  ...
# 11714     Samedi 3 octobre, 10h00  2026-10-03T08:00:00+00:00  ...
# 11717  Mercredi 14 octobre, 09h30  2026-10-14T07:30:00+00:00  ...
#
#       location_postalcode         location_city  \
# 9538                88700                  Bult
# 9566                67000            Strasbourg
# 9582                51000  Châlons-en-Champagne
# 9589                51100                 Reims
# 9592                10000                Troyes
# ...                   ...                   ...
# 11637               57170        Château-Salins
# 11652               52000              Chaumont
# 11676               52220       La Porte du Der
# 11714               55110               Doulcon
# 11717               52000              Chaumont
#
#                     location_department location_region age_min age_max  \
# 9538                             Vosges       Grand Est     NaN     NaN
# 9566   Collectivité européenne d'Alsace       Grand Est     NaN     NaN
# 9582                              Marne       Grand Est     NaN     NaN
# 9589                              Marne       Grand Est     NaN     NaN
# 9592                               Aube       Grand Est     NaN     NaN
# ...                                 ...             ...     ...     ...
# 11637                           Moselle       Grand Est     NaN     6.0
# 11652                       Haute-Marne       Grand Est     NaN     NaN
# 11676                       Haute-Marne       Grand Est     3.0    99.0
# 11714                             Meuse       Grand Est     NaN     NaN
# 11717                       Haute-Marne       Grand Est     NaN     NaN
#
#                                             registration  event_actif  \
# 9538   [{"type": "link", "value": "https://tambouille...         True
# 9566   [{"type": "link", "value": "https://musicamefr...         True
# 9582                                                 NaN         True
# 9589   [{"type": "email", "value": "reservation@frac-...         True
# 9592                                                 NaN         True
# ...                                                  ...          ...
# 11637  [{"type": "email", "value": "rpe@cc-saulnois.f...         True
# 11652                                                NaN         True
# 11676                                                NaN         True
# 11714                                                NaN         True
# 11717  [{"type": "link", "value": "https://www.enviro...         True
#
#                                                texte_rag  \
# 9538   Titre: Tambouille festival\nDescription: festi...
# 9566   Titre: Concert de musique classique à Strasbou...
# 9582   Titre: Concert au Musée du Cloître\nDescriptio...
# 9589   Titre: Visite en musique de l'exposition "Pers...
# 9592   Titre: Rencontres musicales et spirituelles\nD...
# ...                                                  ...
# 11637  Titre: Matinée des Tout-Petits: Pas peur moi !...
# 11652  Titre: Julien Clerc en concert\nDescription: J...
# 11676  Titre: Rouge écharpe\nDescription: Jeune publi...
# 11714  Titre: Visite guidée de la bibliothèque de 10h...
# 11717  Titre: Projection du film documentaire "Des ch...
#
#                           begin
# 9538  2026-08-06 07:00:00+00:00
# 9566  2026-08-14 18:00:00+00:00
# 9582  2026-09-19 13:00:00+00:00
# 9589  2026-09-19 14:00:00+00:00
# 9592  2026-09-19 16:00:00+00:00
# ...                         ...
# 11637 2026-10-21 07:30:00+00:00
# 11652 2026-12-10 19:30:00+00:00
# 11676 2026-12-10 16:00:00+00:00
# 11714 2026-10-03 08:00:00+00:00
# 11717 2026-10-14 07:30:00+00:00
#
# [116 rows x 23 columns]

# %%
df_strasbourg = df_verif[df_verif['location_city'] == 'Strasbourg']
df_strasbourg
# Out:
#        Unnamed: 0       uid  \
# 6               6  79977358
# 19             19   9596870
# 23             23  64666218
# 42             42  36795759
# 54             54  40996137
# ...           ...       ...
# 11673       11673  84772811
# 11682       11682  66227214
# 11721       11721  36722592
# 11725       11725  46629009
# 11730       11730  90089795
#
#                                             canonicalurl  \
# 6      https://openagenda.com/les-evenements-de-la-li...
# 19     https://openagenda.com/unidivers-oui-sortir/ev...
# 23     https://openagenda.com/les-evenements-de-la-li...
# 42     https://openagenda.com/les-evenements-de-la-li...
# 54     https://openagenda.com/les-evenements-de-la-li...
# ...                                                  ...
# 11673  https://openagenda.com/bicentenaire-photograph...
# 11682  https://openagenda.com/culture/events/200-sole...
# 11721  https://openagenda.com/saison-mediterranee-202...
# 11725  https://openagenda.com/panthea/events/thesee-s...
# 11730  https://openagenda.com/bicentenaire-photograph...
#
#                                                 title_fr  \
# 6                       Rencontre avec Roger Fajnzylberg
# 19                             RETRO GAM’IN - STRASBOURG
# 23                            Rencontre avec Roland Gori
# 42                          Rencontre avec Marta Caraion
# 54                           Rencontre avec Marie Nimier
# ...                                                  ...
# 11673          En quête des photographies d'Alice Bommer
# 11682            200 soleils : collecte de photographies
# 11721   Les Faiseuses. Aller-retour Tunis-Strasbourg 2/2
# 11725  THÉSÉE, SA VIE NOUVELLE l Valérie Dréville et ...
# 11730             Une photographe révélée | Alice Bommer
#
#                                           description_fr  \
# 6      Événement gratuit sur inscription via notre si...
# 19     Evènement RETRO GAM'IN - STRASBOURG 2025 le di...
# 23     Événement gratuit sur inscription via notre si...
# 42     Événement gratuit sur inscription via notre si...
# 54     Événement gratuit sur inscription via notre si...
# ...                                                  ...
# 11673                               Informations à venir
# 11682                               Biblis en folie 2026
# 11721  Porté par El Warcha, le projet Les Faiseuses a...
# 11725                  audiodescription sur casque audio
# 11730                                      Texte à venir
#
#                                       longdescription_fr  \
# 6      <p><strong>Événement gratuit sur inscription</...
# 19     <p>Ne manquez pas l'Evènement RETRO GAM'IN - S...
# 23     <p><strong>Événement gratuit sur inscription</...
# 42     <p><strong>Événement gratuit sur inscription</...
# 54     <p><strong>Événement gratuit sur inscription</...
# ...                                                  ...
# 11673  <p>Informations à venir<br>Le vernissage le 06...
# 11682  <p>Cette année, la photographie fête ses 200 a...
# 11721  <p>Porté par El Warcha, le projet Les Faiseuse...
# 11725  <p>Thésée part s’installer à Berlin, la « Vill...
# 11730  <p>Photographe documentaire et de reportage, A...
#
#                                            conditions_fr  \
# 6                                                    NaN
# 19     sur inscription par mail a partir de 15€ le m ...
# 23                                                   NaN
# 42                                                   NaN
# 54                                                   NaN
# ...                                                  ...
# 11673                                                NaN
# 11682                                                NaN
# 11721                                                NaN
# 11725                                     Prix du billet
# 11730                                                NaN
#
#                                                  timings  \
# 6      [{"begin": "2025-02-04T18:00:00+01:00", "end":...
# 19     [{"begin": "2025-03-23T09:00:00+01:00", "end":...
# 23     [{"begin": "2025-03-07T17:30:00+01:00", "end":...
# 42     [{"begin": "2025-03-04T17:00:00+01:00", "end":...
# 54     [{"begin": "2025-02-12T18:00:00+01:00", "end":...
# ...                                                  ...
# 11673  [{"begin": "2026-11-06T18:00:00+01:00", "end":...
# 11682  [{"begin": "2026-10-03T14:00:00+02:00", "end":...
# 11721  [{"begin": "2026-10-21T18:00:00+02:00", "end":...
# 11725  [{"begin": "2026-10-14T20:30:00+02:00", "end":...
# 11730  [{"begin": "2026-11-07T14:00:00+01:00", "end":...
#
#                           daterange_fr            firstdate_begin  ...  \
# 6          Mardi 4 février 2025, 18h00  2025-02-04T17:00:00+00:00  ...
# 19        Dimanche 23 mars 2025, 09h00  2025-03-23T08:00:00+00:00  ...
# 23         Vendredi 7 mars 2025, 17h30  2025-03-07T16:30:00+00:00  ...
# 42            Mardi 4 mars 2025, 17h00  2025-03-04T16:00:00+00:00  ...
# 54     Mercredi 12 février 2025, 18h00  2025-02-12T17:00:00+00:00  ...
# ...                                ...                        ...  ...
# 11673         6 novembre - 25 décembre  2026-11-06T17:00:00+00:00  ...
# 11682          Samedi 3 octobre, 14h00  2026-10-03T12:00:00+00:00  ...
# 11721                  21 - 24 octobre  2026-10-21T16:00:00+00:00  ...
# 11725       Mercredi 14 octobre, 20h30  2026-10-14T18:30:00+00:00  ...
# 11730         7 novembre - 23 décembre  2026-11-07T13:00:00+00:00  ...
#
#                                      location_address location_postalcode  \
# 6               1 rue des Francs Bourgeois,Strasbourg               67000
# 19                                              67100               67100
# 23              1 rue des Francs Bourgeois,Strasbourg               67000
# 42              1 rue des Francs Bourgeois,Strasbourg               67000
# 54              1 rue des Francs Bourgeois,Strasbourg               67000
# ...                                               ...                 ...
# 11673  4 Place d'Austerlitz, 67000 Strasbourg, France               67000
# 11682            3 Rue Kuhn, 67000 Strasbourg, France               67000
# 11721           1, rue de l'Académie 67000 Strasbourg               67000
# 11725         1 boulevard de Dresde, 67000 Strasbourg               67000
# 11730  4 Place d'Austerlitz, 67000 Strasbourg, France               67000
#
#       location_city               location_department location_region age_min  \
# 6        Strasbourg                          Bas-Rhin       Grand Est     NaN
# 19       Strasbourg                          Bas-Rhin       Grand Est     NaN
# 23       Strasbourg                          Bas-Rhin       Grand Est     NaN
# 42       Strasbourg                          Bas-Rhin       Grand Est     NaN
# 54       Strasbourg                          Bas-Rhin       Grand Est     NaN
# ...             ...                               ...             ...     ...
# 11673    Strasbourg                          Bas-Rhin       Grand Est     NaN
# 11682    Strasbourg                          Bas-Rhin       Grand Est     NaN
# 11721    Strasbourg  Collectivité européenne d'Alsace       Grand Est     NaN
# 11725    Strasbourg  Collectivité européenne d'Alsace       Grand Est    14.0
# 11730    Strasbourg                          Bas-Rhin       Grand Est     NaN
#
#       age_max                                       registration  event_actif  \
# 6         NaN  [{"type": "link", "value": "https://www.eventb...        False
# 19       99.0  [{"type": "email", "value": "tandem.events71@g...        False
# 23        NaN  [{"type": "link", "value": "https://www.eventb...        False
# 42        NaN  [{"type": "link", "value": "https://www.eventb...        False
# 54        NaN  [{"type": "link", "value": "https://www.eventb...        False
# ...       ...                                                ...          ...
# 11673     NaN                                                NaN         True
# 11682     NaN                                                NaN         True
# 11721     NaN  [{"type": "link", "value": "https://my.weezeve...         True
# 11725    99.0  [{"type": "email", "value": "mathis.bruneteaux...         True
# 11730     NaN                                                NaN         True
#
#                                                texte_rag
# 6      Titre: Rencontre avec Roger Fajnzylberg\nDescr...
# 19     Titre: RETRO GAM’IN - STRASBOURG\nDescription:...
# 23     Titre: Rencontre avec Roland Gori\nDescription...
# 42     Titre: Rencontre avec Marta Caraion\nDescripti...
# 54     Titre: Rencontre avec Marie Nimier\nDescriptio...
# ...                                                  ...
# 11673  Titre: En quête des photographies d'Alice Bomm...
# 11682  Titre: 200 soleils : collecte de photographies...
# 11721  Titre: Les Faiseuses. Aller-retour Tunis-Stras...
# 11725  Titre: THÉSÉE, SA VIE NOUVELLE l Valérie Drévi...
# 11730  Titre: Une photographe révélée | Alice Bommer\...
#
# [919 rows x 22 columns]

# %%
df_strasbourg_26 =

# %%
max(df_verif["firstdate_begin"])
# Out:
# '2026-12-19T14:00:00+00:00'

# %%
min(df_verif["firstdate_begin"])
# Out:
# '2025-01-01T18:00:00+00:00'

# %%
max(df_verif["lastdate_end"])
# Out:
# '2043-06-04T12:00:00+00:00'

# %%
min(df_verif["lastdate_end"])
# Out:
# '2025-01-04T16:30:00+00:00'

# %%
df_verif['location_city'].unique()
# Out:
# <ArrowStringArray>
# ['Charleville-Mézières',           'Strasbourg',    'Villers-lès-Nancy',
#            'Lapoutroie',                'Laxou',               'Colmar',
#             'Fellering',    'Sainte-Marguerite',                'Reims',
#                 'NANCY',
#  ...
#    'Brienne-la-Vieille',          'Fromelennes',          'Saint-Oulph',
#            'Ortoncourt',         'Willgottheim',        'Pierrevillers',
#       'Montigny le Roi',             'Distroff',                'Lesse',
#      'Bourgogne-Fresne']
# Length: 1391, dtype: str
